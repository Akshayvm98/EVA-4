# %% [markdown]
# <a href="https://colab.research.google.com/github/adithyabalakumar/EVA-4/blob/master/S13/S13B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/theschoolofai/YoloV3.git
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 156, done.
# remote: Total 156 (delta 0), reused 0 (delta 0), pack-reused 156
# Receiving objects: 100% (156/156), 12.74 MiB | 43.93 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import shutil
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.4.0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)

# %%
ls
# Out:
# gdrive/  sample_data/  YoloV3/

# %%
cd YoloV3/
# Out:
# /content/YoloV3

# %%
# !ls
# Out:
#  annotation_tool   output	  results.txt	     train.py
#  cfg		   __pycache__	  test_batch0.png   'ubdivisions=1'
#  data		   README.md	  test.py	     utils
#  detect.py	   results.json   ting		     vim.exe.stackdump
#  models.py	   results.png	  train_batch0.png

# %%
shutil.rmtree('/content/YoloV3/data/customdata')

# %% [markdown]
# Place the weights(yolov3-spp-ultralytics.pt)

# %%
os.mkdir('weights')

# %%
shutil.copy('/content/gdrive/My Drive/Colab Notebooks/S13/yolov3-spp-ultralytics.pt','/content/YoloV3/weights')
# Out:
# '/content/YoloV3/weights/yolov3-spp-ultralytics.pt'

# %% [markdown]
# **Place the data folder with images,labels... in YoloV3/data folder**

# %%
from distutils.dir_util import copy_tree
copy_tree('/content/gdrive/My Drive/Colab Notebooks/S13/custom', '/content/YoloV3/data')
# Out:
# ['/content/YoloV3/data/customdata/custom.data',
#  '/content/YoloV3/data/customdata/custom.shapes',
#  '/content/YoloV3/data/customdata/custom.names',
#  '/content/YoloV3/data/customdata/images/0044.jpg',
#  '/content/YoloV3/data/customdata/images/0058.jpg',
#  '/content/YoloV3/data/customdata/images/0063.jpg',
#  '/content/YoloV3/data/customdata/images/0043.jpg',
#  '/content/YoloV3/data/customdata/images/0055.jpg',
#  '/content/YoloV3/data/customdata/images/0064.jpg',
#  '/content/YoloV3/data/customdata/images/0047.jpg',
#  '/content/YoloV3/data/customdata/images/0045.jpg',
#  '/content/YoloV3/data/customdata/images/0060.jpg',
#  '/content/YoloV3/data/customdata/images/0051.jpg',
#  '/content/YoloV3/data/customdata/images/0042.jpg',
#  '/content/YoloV3/data/customdata/images/0066.jpg',
#  '/content/YoloV3/data/customdata/images/0056.jpg',
#  '/content/YoloV3/data/customdata/images/0050.jpg',
#  '/content/YoloV3/data/customdata/images/0052.jpg',
# ...

# %%
# !ls
# Out:
#  annotation_tool   output	  results.txt	     train.py
#  cfg		   __pycache__	  test_batch0.png   'ubdivisions=1'
#  data		   README.md	  test.py	     utils
#  detect.py	   results.json   ting		     vim.exe.stackdump
#  models.py	   results.png	  train_batch0.png   weights

# %%
# !python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 3 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=3, bucket='', cache_images=True, cfg='cfg/yolov3-spp.cfg', data='data/smalcoco/smalcoco.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-27 11:34:55.310436: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.29987e+07 parameters, 6.29987e+07 gradients
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100% 20/20 [00:00<00:00, 6803.41it/s]
# Caching images (0.0GB): 100% 20/20 [00:00<00:00, 116.84it/s]
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 15 --cache --cfg cfg/yolov3-custom.cfg --epochs 350 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=15, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=350, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-27 11:44:38.094874: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (455 found, 0 missing, 0 empty, 0 duplicate, for 455 images): 100% 455/455 [00:00<00:00, 10581.99it/s]
# Caching images (0.3GB): 100% 455/455 [00:01<00:00, 261.81it/s]
# ...

# %% [markdown]
# **Predict bounding box for test video**

# %%
# !python detect.py --conf-thres 0.1 --output '/content/gdrive/My Drive/pika_output' --names data/customdata/custom.names --source '/content/gdrive/My Drive/Colab Notebooks/S13/Pikachu.mp4'
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/gdrive/My Drive/pika_output', save_txt=False, source='/content/gdrive/My Drive/Colab Notebooks/S13/Pikachu.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/2082) /content/gdrive/My Drive/Colab Notebooks/S13/Pikachu.mp4: 384x512 Done. (0.019s)
# video 1/1 (2/2082) /content/gdrive/My Drive/Colab Notebooks/S13/Pikachu.mp4: 384x512 Done. (0.019s)
# video 1/1 (3/2082) /content/gdrive/My Drive/Colab Notebooks/S13/Pikachu.mp4: 384x512 Done. (0.017s)
# video 1/1 (4/2082) /content/gdrive/My Drive/Colab Notebooks/S13/Pikachu.mp4: 384x512 Done. (0.017s)
# ...

# %%
shutil.copy('/content/YoloV3/weights/yolov3-spp-ultralytics.pt','/content/gdrive/My Drive/Colab Notebooks')
# Out:
# '/content/gdrive/My Drive/Colab Notebooks/yolov3-spp-ultralytics.pt'

# %%
shutil.copy('/content/YoloV3/weights/last.pt','/content/gdrive/My Drive/Colab Notebooks')
# Out:
# '/content/gdrive/My Drive/Colab Notebooks/last.pt'
